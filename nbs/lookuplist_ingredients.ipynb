# %%
import json
path = r'C:\Users\Gianluca\Documents\Hackaton Datapizza\hackapizza_gas\data\processed\recipes.json'
with open(path, "r", encoding="utf-8") as file:
    data = json.load(file)

# %%
with open(path, "r", encoding="utf-8") as file:
    data = json.load(file)
list_ingredients = []
for element in data:
    list_ingredients.append(element.get('recipe_ingredients'))
lista_di_liste = [[1, 2, 3], [4, 5], [6, 7, 8]]
lista_unica = [elemento for sottolista in list_ingredients if sottolista for elemento in sottolista]
sorted(set(lista_unica))
# Out:
# ['alghe_bioluminescenti',
#  'alghe_boluminescenti',
#  'amido_di_stellarion',
#  'baccacedro',
#  'baccacedro_caramellato',
#  'baccatedro',
#  'bacche_di_baccacedro',
#  'balena_spaziale',
#  'biscotti_della_g',
#  'biscotti_della_galassia',
#  'brodo_delicato_di_vero_ghiaccio',
#  'brodo_di_liane_di_plasmodio',
#  'brodo_di_teste_di_idra',
#  'buccia_del_baccacedro',
#  'burrobirra',
#  'car_di_balena_spaziale',
#  'carne_delle_teste_di_idra',
#  'carne_di_balena_spaziale',
#  'carne_di_balena_spaziale_e_di_kraken',
#  'carne_di_draga',
#  'carne_di_drago',
#  'carne_di_drago_speziata',
#  'carne_di_kraken',
#  'carne_di_mucca',
#  'carne_di_mucca_e_drago',
#  'carne_di_xenodonate',
#  'carne_di_xenodonte',
#  'carne_rigenerativa_delle_t_di_idra',
#  'carni_succulenti_di_xenodonte',
#  'carpaccio_di_carne_di_kraken',
#  'carpaccio_di_funghi_orbitali',
#  'chocobo_wings',
#  'cioccorane',
#  'colonia_di_mycoflora',
#  'colonia_di_mycoflora_fermentata_psionicamente',
# ...

# %%
ingredienti = ['alghe_bioluminescenti',
#  'alghe_boluminescenti',
 'amido_di_stellarion',
 'baccacedro',
###  perle_di_baccacedro
#  'baccacedro_caramellato',
#  'baccatedro',
#  'bacche_di_baccacedro',
#  'balena_spaziale',
#  'biscotti_della_g',
 'biscotti_della_galassia',
#  'brodo_delicato_di_vero_ghiaccio',
#  'brodo_di_liane_di_plasmodio',
#  'brodo_di_teste_di_idra',
#  'buccia_del_baccacedro',
 'burrobirra',
#  'car_di_balena_spaziale',
#  'carne_delle_teste_di_idra',
 'carne_di_balena_spaziale',
#  'carne_di_balena_spaziale_e_di_kraken',
#  'carne_di_draga',
 'carne_di_drago',
#  'carne_di_drago_speziata',
 'carne_di_kraken',
 'carne_di_mucca',
#  'carne_di_mucca_e_drago',
#  'carne_di_xenodonate',
 'carne_di_xenodonte',
#  'carne_rigenerativa_delle_t_di_idra',
#  'carni_succulenti_di_xenodonte',
#  'carpaccio_di_carne_di_kraken',
#  'carpaccio_di_funghi_orbitali',
 'chocobo_wings',
 'cioccorane',
#  'colonia_di_mycoflora',
#  'colonia_di_mycoflora_fermentata_psionicamente',
#  'colonies_di_mycoflora',
#  'cottura_a_vapore_ecodinamico_bilanciato',
#  'cottura_a_vapore_termocinetica_multipla',
#  'cristali_di_nebulite',
 'cristalli_di_memoria',
 'cristalli_di_nebulite',
 'cristalli_di_sale_temporale',
#  'drago',
#  'erba',
 'erba_pipa',
 'essenza_di_speziaria',
#  'essenza_di_tach',
 'essenza_di_tachioni',
 'essenza_di_vuoto',
 'farina_di_nettuno',
 'fibra_di_sintetex',
#  'fibra_sintetex',
#  'filetto_di_carne_di_balena_spaziale',
#  'filetto_di_carne_di_kraken',
#  'filetto_di_carne_di_mucca',
#  'filetto_di_carne_di_xenodonte',
#  'filetto_di_vegetali_sublimati',
 'foglie_di_mandragora',
#  'foglie_di_nebula',
 'foglie_di_nebulosa',
#  'frammenti_di_supernov',
 'frammenti_di_supernova',
#  'frutta_e_verdura',
 'frutti_del_diavolo',
 'funghi_dell_etere',
 'funghi_orbitali',
#  'fusill_vento',
 'fusilli_del_vento',
 'ghiaccio_di_criofenice',
 'gnocchi_del_crepuscolo',
#  'granuli_di_nebbia_arcobalenko',
 'granuli_di_nebbia_arcobaleno',
 'impasto_gravitazionale_vorticoso',
#  'incisione_elettromagnetica_plasmica',
 'lacrime_di_andromeda',
 'lacrime_di_unicorno',
 'latte_',
#  'lattuga',
 'lattuga_namecciana',
#  'liane_di_plasmod',
 'liane_di_plasmodio',
#  'marinatura_psionica',
#  'materia_oscura',
#  'muf_lunare',
#  'muffa_lunara',
 'muffa_lunare',
 'mycoflora',
#  'mycoflora_fresca',
 'nduja_fritta_tanto',
#  'nebbia_arcobaleno',
#  'nebula_leaves',
#  'nebulite',
 'nettare_di_sirena',
#  'nettare_sirena',
#  'pane',
 'pane_degli_abissi',
#  'pane_di_farina_di_nettuno',
 'pane_di_luce',
#  'pesto_di_alghe_bioluminescenti',
#  'petali_di_alghe_bioluminescenti',
 'petali_di_eco',
#  'pickle_rick_croccante',
#  'plasm_vitale',
 'plasma_vitale',
#  'polvere_crononite',
 'polvere_di_crononite',
 'polvere_di_pulsar',
#  'polvere_di_stella',
 'polvere_di_stelle',
#  'polvere_effervescente_di_pulsar',
#  'psionica',
#  'pulsar_powder',
#  'puré_di_carne_di_xenodonte',
#  'radi_singolarità',
 'radici_di_gravità',
#  'radici_di_gravità_e_singolarità',
 'radici_di_singolarità',
#  'radici_di_singolarità_e_di_gravità',
 'ravioli_al_vaporeon',
 'raviolo_traslucido',
#  'reazioni_d_antimateria_diluite',
 'riso_di_cassandra',
#  'risotto_dei_multiversi',
#  'risotto_di_alghe_bioluminescenti',
 'sale_temporale',
#  'salsa_nduja_fritta_tanto',
 'salsa_szechuan',
#  'salsa_szechuan_interdimensionale',
#  'salsa_szechuan_sichuan',
#  'sashimi_di_magicarp',
'sashimi_di_magikarp', ###################################################
 'scaglie_di_stelle',
 'scaglie_stellari',
#  'sfera_di_vero_ghiaccio',
 'shard_di_materia_oscura',
 'shard_di_prisma_stellare',
#  'singularity_roots',
#  'sintetex',
#  'slurm',
#  'soufflé_al_vero_ghiaccio',
#  'spaghi_del_sol',
 'spaghi_del_sole',
#  'speziaria',
 'spezie_melange',
 'spore_quantiche',
#  'succo_di_baccacedro',
#  'sugo',
#  'tagliatelle_spaghi_del_sole',
#  'temporal_salt',

 'teste_di_idra',

 'uova_di_fenice',
#  'uovo_di_fenice',
#  'verdure_stagionali',
#  'vero_ghiaccio',
#  'xenodonte',
 'zucchero_cosmico']
ingredienti
# Out:
# ['alghe_bioluminescenti',
#  'amido_di_stellarion',
#  'baccacedro',
#  'biscotti_della_galassia',
#  'burrobirra',
#  'carne_di_balena_spaziale',
#  'carne_di_drago',
#  'carne_di_kraken',
#  'carne_di_mucca',
#  'carne_di_xenodonte',
#  'chocobo_wings',
#  'cioccorane',
#  'cristalli_di_memoria',
#  'cristalli_di_nebulite',
#  'cristalli_di_sale_temporale',
#  'erba_pipa',
#  'essenza_di_speziaria',
#  'essenza_di_tachioni',
#  'essenza_di_vuoto',
#  'farina_di_nettuno',
#  'fibra_di_sintetex',
#  'foglie_di_mandragora',
#  'foglie_di_nebulosa',
#  'frammenti_di_supernova',
#  'frutti_del_diavolo',
#  'funghi_dell_etere',
#  'funghi_orbitali',
#  'fusilli_del_vento',
#  'ghiaccio_di_criofenice',
#  'gnocchi_del_crepuscolo',
#  'granuli_di_nebbia_arcobaleno',
#  'impasto_gravitazionale_vorticoso',
#  'lacrime_di_andromeda',
#  'lacrime_di_unicorno',
#  'latte_',
#  'lattuga_namecciana',
#  'liane_di_plasmodio',
#  'muffa_lunare',
#  'mycoflora',
#  'nduja_fritta_tanto',
# ...

# %%
technique_names = [
    "marinatura a infusione gravitazionale",
    "marinatura temporale sincronizzata",
    "marinatura psionica",
    "marinatura tramite reazioni d antimateria diluite",
    "marinatura sotto zero a polarità inversa",
    "affumicatura a stratificazione quantica",
    "affumicatura temporale risonante",
    "affumicatura psionica sensoriale",
    "affumicatura tramite big bang microcosmico",
    "affumicatura polarizzata a freddo iperbarico",
    "fermentazione quantica a strati multiversali",
    "fermentazione temporale sincronizzata",
    "fermentazione psionica energetica",
    "fermentazione tramite singolarità",
    "fermentazione quantico biometrica",
    "decostruzione atomica a strati energetici",
    "decostruzione magnetica risonante",
    "decostruzione bio-fotonica emotiva",
    "decostruzione ancestrale",
    "decostruzione interdimensionale lovercraftiana",
    "sferificazione a gravità psionica variabile",
    "sferificazione filamentare a molecole vibrazionali",
    "sferificazione cromatica interdimensionale",
    "sferificazione con campi magnetici entropici",
    "sferificazione tramite matrici biofotiche",
    "taglio dimensionale a lame fotofilliche",
    "affettamento a pulsazioni quantistiche",
    "taglico sinaptico biomimetico",
    "incisione elettromagnetica plasmica",
    "impasto gravitazionale vorticoso",
    "amalgamazione sintetica molecolare",
    "impasto a campi magnetici dualistici",
    "sinergia elettro-osmotica programmabile",
    "modellatura onirica tetrazionale",
    "cryo-tessitura energetica polarizzata",
    "congelamento bio-luminiscente sincronico",
    "cristallizzazione temporale reversiva",
    "congelazione iperdimensionalmente stratificata",
    "surgelamento antimaterico a risonanza inversa",
    "ebollizione magneto-cinetica pulsante",
    "bollitura infrasonica armonizzata",
    "bollitura termografica a rotazione veloce",
    "bollitura entropica sincronizzata",
    "idro-cristallizzazione sonora quantistica",
    "grigliatura a energia stellare div",
    "grigliatura plasma sintetico risonante",
    "grigliatura elettro-molecolare a spaziatura variabile",
    "grigliatura tachionica refrattaria",
    "grigliatura psionica dinamica ritmica",
    "cottura al forno con paradosso temporale cronospeculare",
    "cottura con microonde entropiche sincronizzate",
    "cottura a forno dinamico inversionale",
    "cottura olografica quantum fluttuante",
    "cottura geomagnetica psicosincronizzata",
    "cottura a vapore risonante simbiotico",
    "cottura idrodinamica autoregolante",
    "cottura sottovuoto antimateria",
    "cottura sottovuoto multirealità collassante",
    "cottura sottovuoto frugale energeticamente negativa",
    "cottura sottovuoto pulsar magnetica",
    "cottura sottovuoto bioma sintetico",
    "saltare in padella big bang termico",
    "saltare in padella realtà energetiche parallele",
    "saltare in padella singolarità inversa",
    "saltare in padella sinergia psionica",
]
len(technique_names)
# Out:
# 65

# %%
len(ingredienti)
# Out:
# 66

# %%
['alghe_bioluminescenti',
 'amido_di_stellarion',
 'baccacedro',
 'biscotti_della_galassia',
 'burrobirra',
 'carne_di_balena_spaziale',
 'carne_di_drago',
 'carne_di_kraken',
 'carne_di_mucca',
 'carne_di_xenodonte',
 'chocobo_wings',
 'cioccorane',
 'cristalli_di_memoria',
 'cristalli_di_nebulite',
 'cristalli_di_sale_temporale',
 'erba_pipa',
 'essenza_di_speziaria',
 'essenza_di_tachioni',
 'essenza_di_vuoto',
 'farina_di_nettuno',
 'fibra_di_sintetex',
 'foglie_di_mandragora',
 'foglie_di_nebulosa',
 'frammenti_di_supernova',
 'frutti_del_diavolo',
 'funghi_dell_etere',
 'funghi_orbitali',
 'fusilli_del_vento',
 'ghiaccio_di_criofenice',
 'gnocchi_del_crepuscolo',
 'granuli_di_nebbia_arcobaleno',
 'impasto_gravitazionale_vorticoso',
 'lacrime_di_andromeda',
 'lacrime_di_unicorno',
 'latte_',
 'lattuga_namecciana',
 'liane_di_plasmodio',
 'muffa_lunare',
 'mycoflora',
 'nduja_fritta_tanto',
 'nettare_di_sirena',
 'pane_degli_abissi',
 'pane_di_luce',
 'petali_di_eco',
 'plasma_vitale',
 'polvere_di_crononite',
 'polvere_di_pulsar',
 'polvere_di_stelle',
 'radici_di_gravità',
 'radici_di_singolarità',
 'ravioli_al_vaporeon',
 'raviolo_traslucido',
 'riso_di_cassandra',
 'sale_temporale',
 'salsa_szechuan',
 'sashimi_di_magikarp',
 'scaglie_di_stelle',
 'scaglie_stellari',
 'shard_di_materia_oscura',
 'shard_di_prisma_stellare',
 'spaghi_del_sole',
 'spezie_melange',
 'spore_quantiche',
 'teste_di_idra',
 'uova_di_fenice',
 'zucchero_cosmico']

# %%
with open(path, "r", encoding="utf-8") as file:
    data = json.load(file)
list_ingredients = []
for element in data:
    list_ingredients.append(element.get('recipe_techniques'))
lista_di_liste = [[1, 2, 3], [4, 5], [6, 7, 8]]
lista_unica = [elemento for sottolista in list_ingredients if sottolista for elemento in sottolista]
sorted(set(lista_unica))
# Out:
# ['a_vapore_ecodinamico_bilanciato',
#  'affettamento_a_pulsazioni_quantistiche',
#  'affumicata_a_stratificazione_quantica',
#  'affumicato_tramite_un_big_bang_microcosmico',
#  'affumicatura_a_stratificazione_quanti',
#  'affumicatura_a_stratificazione_quantica',
#  'affumicatura_polarizzata_a_freddo_iperbarico',
#  'affumicatura_psionica_sensoriale',
#  'affumicatura_temporal_risonante',
#  'affumicatura_temporale_risonante',
#  'affumicatura_tramite_big_bang_microcosmico',
#  'amalgamazione_sintetica_molecolare',
#  'balletto_di_sfumature_e_sapori',
#  'big_bang_microcosmico',
#  'bollitura_entropica_sincronizzata',
#  'bollitura_infrasonica_armonizzata',
#  'bollitura_termografica_a_rotazione_veloce',
#  'campi_magnetici_dualistici',
#  'campi_magnetici_entropici',
#  'campo_gravitazionale_modulato',
#  'classic_pan_searing',
#  'congelamento_bio_luminiscente_sincronico',
#  'congelamento_bio_luminiscente_sincronizzato',
#  'congelamento_bioluminiscente_sincronico',
# ...

# %%
opop = [
    # 'a_vapore_ecodinamico_bilanciato',
 'affettamento_a_pulsazioni_quantistiche',
#  'affumicata_a_stratificazione_quantica',
#  'affumicato_tramite_un_big_bang_microcosmico',
#  'affumicatura_a_stratificazione_quanti',
 'affumicatura_a_stratificazione_quantica',
 'affumicatura_polarizzata_a_freddo_iperbarico',
 'affumicatura_psionica_sensoriale',
#  'affumicatura_temporal_risonante',
 'affumicatura_temporale_risonante',
 'affumicatura_tramite_big_bang_microcosmico',
 'amalgamazione_sintetica_molecolare',
#  'balletto_di_sfumature_e_sapori',
#  'big_bang_microcosmico',
 'bollitura_entropica_sincronizzata',
 'bollitura_infrasonica_armonizzata',
 'bollitura_termografica_a_rotazione_veloce',
#  'campi_magnetici_dualistici',
#  'campi_magnetici_entropici',
#  'campo_gravitazionale_modulato',
#  'classic_pan_searing',
#  'congelamento_bio_luminiscente_sincronico',
 'congelamento_bio_luminiscente_sincronizzato',
 'congelamento_bioluminiscente_sincronico',
 'congelazione_iperdimensionalmente_stratificata',
#  'controllo_gravitazionale',
#  'cotti_al_vapore_ecodinamico_bilanciato',
#  'cotti_in_microonde_entropiche_sincronizzate',
#  'cotti_sottovuoto_frugalmente_energetico_negativo',
#  'cotto_a_vapore_con_flusso_di_particelle_isoarmoniche',
#  'cotto_con_la_radianza_di_una_stella',
#  'cotto_per_catturare_la_salinità_minerale',
 'cottura_a_forno_dinamico_inversionale',
 'cottura_a_vapore_con_flusso_di_particelle_isoarmoniche',
 'cottura_a_vapore_con_vapore_ecodinamico_bilanciato',
#  'cottura_a_vapore_ecodi_bilanciato',
 'cottura_a_vapore_ecodinamico_bilanciato',
#  'cottura_a_vapore_rison_simbiotico',
 'cottura_a_vapore_risonante_simbiotico',
 'cottura_a_vapore_termocinetica_multipla',
#  'cottura_a_vapore_termocinetica_multipla_',
#  'cottura_a_vapore_termocinetico_multiplo',
 'cottura_al_forno_con_paradosso_temporale_cronospeculare',
 'cottura_con_microonde_entropiche_sincronizzate',
 'cottura_idrodinamica_autoregolante',
#  'cottura_microonde_entropiche_sincronizzate',
 'cottura_olografica_quantum_fluttuante',
 'cottura_sotto_la_luce_di_una_stella',
 'cottura_sottovuoto_antimateria',
 'cottura_sottovuoto_bioma_sintetico',
#  'cottura_sottovuoto_con_tecnica_del_bioma_sintetico',
#  'cottura_sottovuoto_con_tecnica_frugale_energeticamente_negativa',
 'cottura_sottovuoto_frugale_energeticamente_negativa',
 'cottura_sottovuoto_multirealità_collassante',
 'cottura_sottovuoto_pulsar_magnetica',
#  'cottura_sottovuoto_pulsar_magnetica_',
 'cristallizzazione_temporale_reversiva',
#  'cryo_tessitura_energetica_polarizzata',
 'cryotessitura_energetica_polarizzata',
 'decostruzione_ancestrale',
 'decostruzione_atomica_a_strati_energetici',
 'decostruzione_bio_fotonica_emotiva',
 'decostruzione_interdimensionale_lovecraftiana',
 'decostruzione_magnetica_risonante',
 'ebollizione_magneto_cinetica_pulsante',
#  'essenza_di_speziaria',
#  'essenza_di_tachioni',
 'fermentazione_psionica_energetica',
 'fermentazione_quantica_a_strati_multiversali',
 'fermentazione_quantico_biometrica',
 'fermentazione_temporale_sincronizzata',
#  'flusso_di_particelle_isoarmoniche',
#  'forno_dinamico_inversionale',
#  'frammentati_di_cristalli_puri_di_vero_ghiaccio',
#  'gocce_di_salse_levitano',
#  'gravitazionale_i_',
 'gravitazione_controllata',
 'grigliatura_a_energia_stellare',
#  'grigliatura_a_energia_stellare_div',
#  'grigliatura_eletro_molecolare_a_spaziatura_variabile',
 'grigliatura_elettro_molecolare_a_spaziatura_variabile',
 'grigliatura_plasma_sintetico_risonante',
 'grigliatura_psionica_dinamica_ritmica',
#  'idro_cristallizzazione_sonora_quantistica',
 'idrocristallizzazione_sonora_quantistica',
 'impasto_a_campi_magnetici_dualistici',
 'impasto_gravitazionale_vorticoso',
#  'impasto_gravitazionale_vorticoso_',
 'incisione_elettromagnetica_plasmica',
 'incisioni_elettromagnetiche_plasmatiche',
#  'latte_',
#  'levità_grazie_alla_maestria_gravitazionale',
#  'lievitato_con_la_stessa_luminescenza_di_una_stella_lontana',
#  'luce_i_',
#  'luce_ii',
#  'luce_ultravioletta',
 'manipolazione_gravitazionale',
#  'manipolazioni_della_luce_i_',
#  'marinata_a_infusione_gravitazionale',
#  'marinata_in_una_bolla_temporale_sincronizzata',
#  'marinata_nel_nettare_di_sirena',
#  'marinate_con_polvere_di_pulsar',
#  'marinate_under_zero_a_polarità_inversa',
#  'marination_via_diluted_antimatter_reactions',
#  'marinato_attraverso_reazioni_d_antimateria_diluite',
 'marinatura_a_infusione_gravitazionale',
 'marinatura_psionica',
 'marinatura_sotto_zero_a_polarità_inversa',
 'marinatura_temporale_sincronizzata',
 'marinatura_tramite_reazioni_d_antimateria_diluite',
#  'metodo_a_frequenze_elettromagnetiche',
#  'microonde_entropiche_sincronizzate',
#  'miniaturizzato',
#  'modellato_oniricamente_tetrazionale',
 'modellatura_onirica_tetrazionale',
#  'nduja_fritta_tanto',
#  'padella_in_maniera_classica',
#  'pane_di_luce_cotto_con_raggi_stellari',
#  'plasma_vitale',
 'polarizzazione_a_freddo_iperbarico',
#  'polvere_di_stelle',
#  'presentazione_sospesa',
#  'proiezioni_olografiche_quantum_fluttuanti',
#  'pulsante_magneto_cinetica',
#  'pulsazioni_quantistiche',
#  'raffreddata_tramite_vero_ghiaccio',
#  'realtà_energetiche_parallele',
#  'reazioni_d_antimateria_diluite',
#  'riduzione_di_essenza_di_tachioni',
#  'sale_temporale',
#  'salsa_szechuan',
#  'saltare_in_padella',
#  'saltare_in_padella_classica',
#  'saltare_in_padella_realtà_energetiche_parallele',
#  'saltare_in_padella_siner_psionica',
#  'saltare_in_padella_singolarità_inversa',
#  'saltata_con_la_tecnica_tradizionale_in_padella',
#  'saltata_manovralmente_alla_perfezione_in_padella',
#  'saltati_in_padella',
#  'saltato_in_padella_in_maniera_classica',
 'sferificazione_a_gravità_psionica_variabile',
 'sferificazione_con_campi_magnetici_entropici',
#  'sferificazione_con_campi_magnetici_entropici_',
 'sferificazione_cromatica_interdimensionale',
 'sferificazione_filamentare_a_molecole_vibrazionali',
 'sferificazione_tramite_matrici_biofotiche',
#  'sinergia_elettro_oosmotica_programmabile',
#  'sinergia_elettro_osmotica_programmabile',
#  'sinergia_elettroosmotica_programmabile',
#  'sinergia_psionica',
#  'sottovuoto_antimateria',
#  'spolverata_di_polvere_di_crononite_e_cristalli_di_sale_temporale',
 'stratificazione_quantica',
#  'superposizione_culinaria_quantistica',
 'surgelamento_antimaterico_a_risonanza_inversa',
 'taglio_a_risonanza_sonica_rigenerativa',
 'taglio_dimensionale_a_lame_fotofiliche',
 'taglio_sinaptico_biomimetico',]
#  'tecnica_di_sinergia_elettro_osmotica_programmabile',
#  'tocco_vibrante',
#  'trattamento_con_spore_quantiche',
#  'vapore_con_flusso_di_particelle_isoarmoniche']

# %%
['affettamento_a_pulsazioni_quantistiche',
 'affumicatura_a_stratificazione_quantica',
 'affumicatura_polarizzata_a_freddo_iperbarico',
 'affumicatura_psionica_sensoriale',
 'affumicatura_temporale_risonante',
 'affumicatura_tramite_big_bang_microcosmico',
 'amalgamazione_sintetica_molecolare',
 'bollitura_entropica_sincronizzata',
 'bollitura_infrasonica_armonizzata',
 'bollitura_termografica_a_rotazione_veloce',
 'congelamento_bio_luminiscente_sincronizzato',
 'congelamento_bioluminiscente_sincronico',
 'congelazione_iperdimensionalmente_stratificata',
 'cottura_a_forno_dinamico_inversionale',
 'cottura_a_vapore_con_flusso_di_particelle_isoarmoniche',
 'cottura_a_vapore_con_vapore_ecodinamico_bilanciato',
 'cottura_a_vapore_ecodinamico_bilanciato',
 'cottura_a_vapore_risonante_simbiotico',
 'cottura_a_vapore_termocinetica_multipla',
 'cottura_al_forno_con_paradosso_temporale_cronospeculare',
 'cottura_con_microonde_entropiche_sincronizzate',
 'cottura_idrodinamica_autoregolante',
 'cottura_olografica_quantum_fluttuante',
 'cottura_sotto_la_luce_di_una_stella',
 'cottura_sottovuoto_antimateria',
 'cottura_sottovuoto_bioma_sintetico',
 'cottura_sottovuoto_frugale_energeticamente_negativa',
 'cottura_sottovuoto_multirealità_collassante',
 'cottura_sottovuoto_pulsar_magnetica',
 'cristallizzazione_temporale_reversiva',
 'cryotessitura_energetica_polarizzata',
 'decostruzione_ancestrale',
 'decostruzione_atomica_a_strati_energetici',
 'decostruzione_bio_fotonica_emotiva',
 'decostruzione_interdimensionale_lovecraftiana',
 'decostruzione_magnetica_risonante',
 'ebollizione_magneto_cinetica_pulsante',
 'fermentazione_psionica_energetica',
 'fermentazione_quantica_a_strati_multiversali',
 'fermentazione_quantico_biometrica',
 'fermentazione_temporale_sincronizzata',
 'gravitazione_controllata',
 'grigliatura_a_energia_stellare',
 'grigliatura_elettro_molecolare_a_spaziatura_variabile',
 'grigliatura_plasma_sintetico_risonante',
 'grigliatura_psionica_dinamica_ritmica',
 'idrocristallizzazione_sonora_quantistica',
 'impasto_a_campi_magnetici_dualistici',
 'impasto_gravitazionale_vorticoso',
 'incisione_elettromagnetica_plasmica',
 'incisioni_elettromagnetiche_plasmatiche',
 'manipolazione_gravitazionale',
 'marinatura_a_infusione_gravitazionale',
 'marinatura_psionica',
 'marinatura_sotto_zero_a_polarità_inversa',
 'marinatura_temporale_sincronizzata',
 'marinatura_tramite_reazioni_d_antimateria_diluite',
 'modellatura_onirica_tetrazionale',
 'polarizzazione_a_freddo_iperbarico',
 'sferificazione_a_gravità_psionica_variabile',
 'sferificazione_con_campi_magnetici_entropici',
 'sferificazione_cromatica_interdimensionale',
 'sferificazione_filamentare_a_molecole_vibrazionali',
 'sferificazione_tramite_matrici_biofotiche',
 'stratificazione_quantica',
 'surgelamento_antimaterico_a_risonanza_inversa',
 'taglio_a_risonanza_sonica_rigenerativa',
 'taglio_dimensionale_a_lame_fotofiliche',
 'taglio_sinaptico_biomimetico']
# Out:
# ['affettamento_a_pulsazioni_quantistiche',
#  'affumicatura_a_stratificazione_quantica',
#  'affumicatura_polarizzata_a_freddo_iperbarico',
#  'affumicatura_psionica_sensoriale',
#  'affumicatura_temporale_risonante',
#  'affumicatura_tramite_big_bang_microcosmico',
#  'amalgamazione_sintetica_molecolare',
#  'bollitura_entropica_sincronizzata',
#  'bollitura_infrasonica_armonizzata',
#  'bollitura_termografica_a_rotazione_veloce',
#  'congelamento_bio_luminiscente_sincronizzato',
#  'congelamento_bioluminiscente_sincronico',
#  'congelazione_iperdimensionalmente_stratificata',
#  'cottura_a_forno_dinamico_inversionale',
#  'cottura_a_vapore_con_flusso_di_particelle_isoarmoniche',
#  'cottura_a_vapore_con_vapore_ecodinamico_bilanciato',
#  'cottura_a_vapore_ecodinamico_bilanciato',
#  'cottura_a_vapore_risonante_simbiotico',
#  'cottura_a_vapore_termocinetica_multipla',
#  'cottura_al_forno_con_paradosso_temporale_cronospeculare',
#  'cottura_con_microonde_entropiche_sincronizzate',
# ...
